# %%
import matplotlib.pyplot as plt

img = plt.imread('/media/gamedisk/M2_internship/bdd100k_seg/bdd100k/seg/images/val/7d2f7975-e0c1c5a7.jpg')
gt = plt.imread('/media/gamedisk/M2_internship/bdd100k_seg/bdd100k/seg/color_labels/val/7d2f7975-e0c1c5a7_train_color.png')
mask = plt.imread('/media/gamedisk/M2_internship/U-FasterKAN/Seg_UKAN/outputs/bdd100k_UKAN/out_val/7d2f7975-e0c1c5a7_pred.png')

#plot 3 figures: input image, predicted mask, ground truth mask

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title('Input Image')
plt.imshow(img)
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title('Predicted Mask')
plt.imshow(mask)
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title('Ground Truth Mask')
plt.imshow(gt)
plt.axis('off') 
plt.show()
